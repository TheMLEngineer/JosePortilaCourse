# %% [markdown]
# # Blue Mission Overview
#
# Looks like the email reply had two links:
#
# https://drive.google.com/file/d/15YyLqIuGlsCLr4ioKUeHRw8H2QjBNOz2/view
#
# https://drive.google.com/file/d/128MRLNuytoW7dVm6B7AF_cDVMeACyTFk/view
#
# See if you can figure out how to use these images to figure out the next step.
#
# Best of luck!

# %%
from PIL import Image

# %%
ls
# Out:
# 00-Overview-of-Working-with-Images.ipynb  Blue_Mission_Files/  pencils.jpg
# 01-Blue-Mission-Overview.ipynb            cover_image.PNG      red_color.jpg
# 02-Blue-Mission-Debrief.ipynb             example.jpg
# blue_color.png                            image_link.PNG

# %%
image = Image.open('image_link.PNG')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x777 at 0x7F46495C6950>

# %%
cover_image = Image.open('cover_image.PNG')

# %%
cover_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1093x693 at 0x7F46495C61D0>

# %%
cover_image.putalpha(128)

# %%
image.paste(im = cover_image , box = (0,0) , mask = cover_image)

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x777 at 0x7F46495C6950>

# %%
# As sizes varrying I am resizing

# %%
image = Image.open('image_link.PNG')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x777 at 0x7F46496315D0>

# %%
#cover_image = Image.open('')

# %%
#cover_image = cover_image.putalpha(128)

# %%
#cover_image

# %%
image = image.resize(cover_image.size)

# %%
image.paste(im = cover_image, box = (0 ,0) , mask = cover_image)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGBA size=1093x693 at 0x7F4649631FD0>
