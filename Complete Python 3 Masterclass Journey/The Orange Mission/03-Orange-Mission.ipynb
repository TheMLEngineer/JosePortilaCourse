# %% [markdown]
# # Orange Mission

# %% [markdown]
# Using the hidden link in the blog post, it looks like we have a new riddle to solve. Download and unzip the file from the link.
#
# Let's see what we can figure out from it.
#
# Best of luck Agent!

# %%
import os
import zipfile
import shutil

# %%
zip_obj = zipfile.ZipFile('unzip_me_for_instructions.zip' , 'r')

# %%
zip_obj.extractall('extracted_foler')

# %%
os.getcwd()
# Out:
# '/home/karthikeyan/Documents/Udemy/Python 3 MasterClass/Python-Narrative-Journey-master/11-Orange-Mission-Regular-Expressions-and-Reading-Files'

# %%
import re

# %%
for folder , sub_folders , files in os.walk('/home/karthikeyan/Documents/Udemy/Python 3 MasterClass/Python-Narrative-Journey-master/11-Orange-Mission-Regular-Expressions-and-Reading-Files/extracted_foler/'):
    print('Currently looking at folder : ')
    print(folder)
    print('Subfolders here are : ')
    for sub_folder in sub_folders:
        print(sub_folder)
    print()
    for f in files:
        print(f)
    print()
# Out:
# Currently looking at folder :
# /home/karthikeyan/Documents/Udemy/Python 3 MasterClass/Python-Narrative-Journey-master/11-Orange-Mission-Regular-Expressions-and-Reading-Files/extracted_foler/
# Subfolders here are :
# One
# Four
# Two
# Five
# Three
#
# Instructions.txt
#
# Currently looking at folder :
# /home/karthikeyan/Documents/Udemy/Python 3 MasterClass/Python-Narrative-Journey-master/11-Orange-Mission-Regular-Expressions-and-Reading-Files/extracted_foler/One
# Subfolders here are :
#
# HFUTPPAXDIS.txt
# HDOHZHFSTTK.txt
# PQNVCVJINAR.txt
# PTOBBCJYURJ.txt
# HVUTZEVMSBW.txt
# JTHSNBNPQSE.txt
# JDLRVFCXYLU.txt
# JEHBLZPUPSP.txt
# KFIUZFERLET.txt
# LIFDHOFKWOI.txt
# LFEATJAAYDC.txt
# JLTXKIGCWDL.txt
# KMMLGJOWLGI.txt
# LHODFIKVTQA.txt
# PLYCGPVEAWO.txt
# KTXDHIOKAUI.txt
# PDJMSMNKIRM.txt
# KCXGNQCZBLO.txt
# HMNZTLIFGPD.txt
# LDGOCUQJNNS.txt
# HRQFTHKVJTL.txt
# KNBSKDREHQU.txt
# PHWAVPEKAER.txt
# JQUOBKFUACN.txt
# LPNDVDXPZIG.txt
#
# Currently looking at folder :
# ...

# %%
for folder , sub_folders , files in os.walk('/home/karthikeyan/Documents/Udemy/Python 3 MasterClass/Python-Narrative-Journey-master/11-Orange-Mission-Regular-Expressions-and-Reading-Files/extracted_foler/'):
    print('Currently looking at folder : ')
    print(folder)
    print('Subfolders here are : ')
    for sub_folder in sub_folders:
        print(sub_folder)
    print()
    for f in files:
        file = open(folder + '/' + str(f))
        print(re.findall(r'https://' , file.read()))
        file.close()
    print()
# Out:
# Currently looking at folder :
# /home/karthikeyan/Documents/Udemy/Python 3 MasterClass/Python-Narrative-Journey-master/11-Orange-Mission-Regular-Expressions-and-Reading-Files/extracted_foler/
# Subfolders here are :
# One
# Four
# Two
# Five
# Three
#
# ['https://', 'https://', 'https://']
#
# Currently looking at folder :
# /home/karthikeyan/Documents/Udemy/Python 3 MasterClass/Python-Narrative-Journey-master/11-Orange-Mission-Regular-Expressions-and-Reading-Files/extracted_foler/One
# Subfolders here are :
#
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
#
# Currently looking at folder :
# /home/karthikeyan/Documents/Udemy/Python 3 MasterClass/Python-Narrative-Journey-master/11-Orange-Mission-Regular-Expressions-and-Reading-Files/extracted_foler/Four
# Subfolders here are :
#
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
#
# ...

# %%
for folder , sub_folders , files in os.walk('/home/karthikeyan/Documents/Udemy/Python 3 MasterClass/Python-Narrative-Journey-master/11-Orange-Mission-Regular-Expressions-and-Reading-Files/extracted_foler/'):
    print('Currently looking at folder : ')
    print(folder)
    print('Subfolders here are : ')
    for sub_folder in sub_folders:
        print(sub_folder)
    print()
    for f in files:
        file = open(folder + '/' + str(f))
        print(re.findall(r'https://[-?_=./\w]+' , file.read()))
        file.close()
    print()
# Out:
# Currently looking at folder :
# /home/karthikeyan/Documents/Udemy/Python 3 MasterClass/Python-Narrative-Journey-master/11-Orange-Mission-Regular-Expressions-and-Reading-Files/extracted_foler/
# Subfolders here are :
# One
# Four
# Two
# Five
# Three
#
# ['https://drive.google.com/open?id=1tWJBFrSQL06qTZgkohs4t_a5Cu84AheLo', 'https://docs.google.com/document/d/Q-DcxM17nJm_El0aGsNnY7FajaogRviwja/edit']
#
# Currently looking at folder :
# /home/karthikeyan/Documents/Udemy/Python 3 MasterClass/Python-Narrative-Journey-master/11-Orange-Mission-Regular-Expressions-and-Reading-Files/extracted_foler/One
# Subfolders here are :
#
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
#
# Currently looking at folder :
# /home/karthikeyan/Documents/Udemy/Python 3 MasterClass/Python-Narrative-Journey-master/11-Orange-Mission-Regular-Expressions-and-Reading-Files/extracted_foler/Four
# Subfolders here are :
#
# []
# []
# []
# ...

# %% [markdown]
# <h2>The two links are </h2>
# <a href= "https://docs.google.com/document/d/1tWJBFrSQL06qTZgkohs4t_a5Cu84AheLocWTXQ-DcxM/edit "> https://docs.google.com/document/d/1tWJBFrSQL06qTZgkohs4t_a5Cu84AheLocWTXQ-DcxM/edit </a>
# <p>
# <a href = "https://drive.google.com/file/d/17nJm_El0aGsNvaMZtnY7FajaogRviwja/view" > https://drive.google.com/file/d/17nJm_El0aGsNvaMZtnY7FajaogRviwja/view </a>
